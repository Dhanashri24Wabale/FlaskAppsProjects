# %%
from pandas import read_csv
import pandas as pd
import numpy as np
df= pd.read_csv("Uber Drives 2016.csv")

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.shape
# Out:
# (1155, 7)

# %%
df.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %% [markdown]
# CHANGING THE DATATYPES

# %%
temp=pd.DataFrame({"A":["1","2","3"],"B":[11,22,33],"C":["12-06-2012","13-06-2015","15-06-2017"]})

# %%
temp
# Out:
#    A   B           C
# 0  1  11  12-06-2012
# 1  2  22  13-06-2015
# 2  3  33  15-06-2017

# %%
temp.dtypes
# Out:
# A    object
# B     int64
# C    object
# dtype: object

# %%
pd.to_datetime("2016-jun-02")
# Out:
# Timestamp('2016-06-02 00:00:00')

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\asus\\anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
temp["C"]=pd.to_datetime(temp["C"])
temp
temp.dtypes
#pd.to_datetime(["2016-sep-11","abc"])
pd.to_datetime(["2016-sep-11","abc"],errors="coerce")
# Out:
# DatetimeIndex(['2016-09-11', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
temp["A"]=pd.to_numeric(temp["A"])

# %%
temp.dtypes
# Out:
# A             int64
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
temp["A"]=temp["A"].astype(str)

# %%
temp.dtypes
# Out:
# A            object
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
# convert data to date time format
pd.to_datetime(df["START_DATE*"],format='%m/%d/%Y %H:%M')
pd
# Out:
# <module 'pandas' from 'C:\\Users\\asus\\anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %% [markdown]
# DATA SUMMARIZATION METHOD

# %%
df.describe(include='all')
# Out:
#             START_DATE*        END_DATE* CATEGORY* START* STOP*       MILES*  \
# count              1155             1155      1155   1155  1155  1155.000000
# unique             1154             1154         2    176   187          NaN
# top     6/28/2016 23:34  6/28/2016 23:59  Business   Cary  Cary          NaN
# freq                  2                2      1078    201   203          NaN
# mean                NaN              NaN       NaN    NaN   NaN    10.566840
# std                 NaN              NaN       NaN    NaN   NaN    21.579106
# min                 NaN              NaN       NaN    NaN   NaN     0.500000
# 25%                 NaN              NaN       NaN    NaN   NaN     2.900000
# 50%                 NaN              NaN       NaN    NaN   NaN     6.000000
# 75%                 NaN              NaN       NaN    NaN   NaN    10.400000
# max                 NaN              NaN       NaN    NaN   NaN   310.300000
#
#        PURPOSE*
# count       653
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
#count of unique start locations
df["START*"].value_counts().head()
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
# Name: START*, dtype: int64

# %% [markdown]
#               COMMON DATA MANIPULATION TASKS

# %% [markdown]
# 5 VERBS OF DATA MANIPULATION
#
# 1.SELECTING /INDEXING
# 2.FILTERING
# 3.SORTING.
# 4.MUTATING/CONDITIONALLY ADDING COLUMNS
# 5.GROUPBY/SUMMARIZE

# %% [markdown]
# SELECT/INDEXING
#
# TWO METHOS INTO THIS SELECT/INDEXING
# 1)iloc
# 2)loc

# %%
df.iloc[0:5,0:4]
#here first part in square bracket is row index range and second part is column index range
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce

# %%
df.iloc[0:5,[0,3]]
# Out:
#       START_DATE*       START*
# 0  1/1/2016 21:11  Fort Pierce
# 1   1/2/2016 1:25  Fort Pierce
# 2  1/2/2016 20:25  Fort Pierce
# 3  1/5/2016 17:31  Fort Pierce
# 4  1/6/2016 14:42  Fort Pierce

# %%
df.iloc[0:4]
# here we are only passing the row index ranges that means row from index 0 to 3 displays and all columns displays as col range is not mentioned
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*        STOP*  MILES*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce  Fort Pierce     5.1
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce  Fort Pierce     5.0
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce  Fort Pierce     4.8
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce  Fort Pierce     4.7
#
#           PURPOSE*
# 0   Meal/Entertain
# 1              NaN
# 2  Errand/Supplies
# 3          Meeting

# %%
df.iloc[:,0:4]
#here all rows displays and col range is from index 0 to 3 for displaying the values
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
# [1155 rows x 4 columns]

# %%
 df.iloc[:,: -1]
# displays all the rows and col except the last one
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*
# 0          Fort Pierce     5.1
# 1          Fort Pierce     5.0
# 2          Fort Pierce     4.8
# ...

# %%
## Positioning indexing
df.iloc[0:4,[0,1]]
# Out:
#       START_DATE*       END_DATE*
# 0  1/1/2016 21:11  1/1/2016 21:17
# 1   1/2/2016 1:25   1/2/2016 1:37
# 2  1/2/2016 20:25  1/2/2016 20:38
# 3  1/5/2016 17:31  1/5/2016 17:45

# %%
#Label base indexing
df.loc[:,"START*"]
# Out:
# 0            Fort Pierce
# 1            Fort Pierce
# 2            Fort Pierce
# 3            Fort Pierce
# 4            Fort Pierce
#               ...
# 1150             Karachi
# 1151             Karachi
# 1152    Unknown Location
# 1153          Katunayake
# 1154             Gampaha
# Name: START*, Length: 1155, dtype: object

# %%
df.loc[:,"START*"]
# Out:
# 0            Fort Pierce
# 1            Fort Pierce
# 2            Fort Pierce
# 3            Fort Pierce
# 4            Fort Pierce
#               ...
# 1150             Karachi
# 1151             Karachi
# 1152    Unknown Location
# 1153          Katunayake
# 1154             Gampaha
# Name: START*, Length: 1155, dtype: object

# %%
df.loc[:,["START*","STOP*"]]
df[["START*","STOP*"]]
#same answer for both the rows
#to convert input 59 i.e above cell which is in the series type into the dataframe use below row
abc=df.loc[:,["START*"]]
type(abc)
abc
#see the diff bet out 60 and out 59 -- in 60 you are having output in theproper data frame format and in out 59 you are having output in series format
# Out:
#                 START*
# 0          Fort Pierce
# 1          Fort Pierce
# 2          Fort Pierce
# 3          Fort Pierce
# 4          Fort Pierce
# ...                ...
# 1150           Karachi
# 1151           Karachi
# 1152  Unknown Location
# 1153        Katunayake
# 1154           Gampaha
#
# [1155 rows x 1 columns]

# %%
xyz=df.loc[:,("START*","STOP*")]
type(xyz)
xyz
# Out:
#                 START*             STOP*
# 0          Fort Pierce       Fort Pierce
# 1          Fort Pierce       Fort Pierce
# 2          Fort Pierce       Fort Pierce
# 3          Fort Pierce       Fort Pierce
# 4          Fort Pierce   West Palm Beach
# ...                ...               ...
# 1150           Karachi           Karachi
# 1151           Karachi  Unknown Location
# 1152  Unknown Location  Unknown Location
# 1153        Katunayake           Gampaha
# 1154           Gampaha         Ilukwatta
#
# [1155 rows x 2 columns]

# %% [markdown]
#                    IN CLASS ASSIGNMENT
#
#        Extract first five rows and columns START_DATE and MILES

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
df.iloc[0:5,[0,5]]
df.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
df.loc[0:4,["START_DATE*","MILES*"]]
# Out:
#       START_DATE*  MILES*
# 0  1/1/2016 21:11     5.1
# 1   1/2/2016 1:25     5.0
# 2  1/2/2016 20:25     4.8
# 3  1/5/2016 17:31     4.7
# 4  1/6/2016 14:42    63.7

# %% [markdown]
#      FILTERING

# %%
df["MILES*"]>10
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1150    False
# 1151    False
# 1152     True
# 1153    False
# 1154     True
# Name: MILES*, Length: 1155, dtype: bool

# %%
df2=df.loc[df["MILES*"]>10,["MILES*"]]
df2
# Out:
#       MILES*
# 4       63.7
# 9       16.5
# 10      10.8
# 22      15.1
# 23      11.2
# ...      ...
# 1133    11.6
# 1134    11.9
# 1144    12.9
# 1152    16.2
# 1154    48.2
#
# [315 rows x 1 columns]

# %%
#find out all rides from New York
df.loc[df["START*"]=="New York",["MILES*"]].head()
# Out:
#      MILES*
# 10     10.8
# 22     15.1
# 106    13.0
# 423    16.3

# %%
#Find out all rides to carry & Morrisville
my_rides=df[df["START*"].isin(["Carry","Morrisville"])].shape
my_rides
# Out:
# (85, 7)

# %%
#Find out all rides to carry & Morrisville
my_rides=df[df["START*"].isin(["Carry","Morrisville"])]
my_rides.iloc[0:5,:]
my_rides.loc[0:5,:]
# Out:
# Empty DataFrame
# Columns: [START_DATE*, END_DATE*, CATEGORY*, START*, STOP*, MILES*, PURPOSE*]
# Index: []

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %% [markdown]
# ************IN CLASS ASSIGNMENT******************
# 1.find all trips with distance >10 miles and originating from carry and morrisville
# 2.Extract top three rows from the filtered dataset

# %%
# 1st assignment anw
df3=df.loc[(df["MILES*"]>10)&(df["START*"].isin(["Cary","Morrisville"]))]
#If we type df3.reset_index() - here we are not able to change the original dataframe 
#after running above line and after typing df3 the original dataframe remains same so follow below steps
df3.reset_index(inplace=True,drop=True)
df3
# Out:
#          START_DATE*         END_DATE* CATEGORY* START*          STOP*  \
# 0    1/15/2016 11:43   1/15/2016 12:03  Business   Cary         Durham
# 1    1/20/2016 10:36   1/20/2016 11:11  Business   Cary        Raleigh
# 2    1/27/2016 10:19   1/27/2016 10:48  Business   Cary        Raleigh
# 3    1/28/2016 12:28   1/28/2016 13:00  Business   Cary        Raleigh
# 4    1/29/2016 11:43   1/29/2016 12:03  Business   Cary         Durham
# ..               ...               ...       ...    ...            ...
# 61  11/22/2016 15:51  11/22/2016 16:43  Business   Cary           Cary
# 62  11/25/2016 11:47  11/25/2016 12:04  Business   Cary         Durham
# 63   12/9/2016 22:03   12/9/2016 22:57  Business   Cary           Cary
# 64  12/10/2016 12:43  12/10/2016 13:16  Business   Cary  Fuquay-Varina
# 65  12/15/2016 14:20  12/15/2016 14:54  Business   Cary    Morrisville
#
#     MILES*        PURPOSE*
# 0     10.4  Meal/Entertain
# 1     17.1         Meeting
# 2     18.7  Customer Visit
# ...

# %% [markdown]
# ******************SORTING**************************

# %%
df.sort_values(by=["MILES*"],ascending =False).head(5)
# Out:
#           START_DATE*         END_DATE* CATEGORY*            START*  \
# 269   3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270   3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881  10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776   9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# 546   7/14/2016 16:39   7/14/2016 20:05  Business       Morrisville
#
#                 STOP*  MILES*        PURPOSE*
# 269      Jacksonville   310.3  Customer Visit
# 270         Kissimmee   201.0         Meeting
# 881            Mebane   195.9             NaN
# 776  Unknown Location   195.6             NaN
# 546        Banner Elk   195.3             NaN

# %%
df.sort_values(by=["START*","MILES*"],ascending=[True,False]).head(5)
# Out:
#           START_DATE*         END_DATE* CATEGORY*  START*        STOP*  \
# 906   11/4/2016 21:04   11/4/2016 21:20  Business   Agnew         Cory
# 911   11/6/2016 10:50   11/6/2016 11:04  Business   Agnew  Renaissance
# 908    11/5/2016 8:34    11/5/2016 8:43  Business   Agnew  Renaissance
# 910   11/5/2016 19:20   11/5/2016 19:28  Business   Agnew        Agnew
# 879  10/30/2016 12:58  10/30/2016 13:18  Business  Almond  Bryson City
#
#      MILES* PURPOSE*
# 906     4.3      NaN
# 911     2.4      NaN
# 908     2.2      NaN
# 910     2.2      NaN
# 879    15.2      NaN

# %% [markdown]
# ************conditionally adding columns***************

# %%
import numpy as np
df["miles_cat"]=np.where(df["MILES*"]>5,"Long Trip","Short Trip")

# %%
    df.head(30)
    df["My_year"]=np.array(2000)
    df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*   miles_cat  My_year
# 0          Fort Pierce     5.1   Meal/Entertain   Long Trip     2000
# ...

# %% [markdown]
# *************IN CLASS ASSIGNMENT*******************

# %%
df["NewMiles"]=np.where(df["MILES*"]<5,"Short",np.where(df["MILES*"]==5,"Medium Trip","Long Trip") )
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*   miles_cat  My_year  \
# ...

# %% [markdown]
# *************GROUPING*********************==>S A C== Split Apply Combine

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*   miles_cat  My_year     NewMiles
# 0     5.1   Meal/Entertain   Long Trip     2000    Long Trip
# 1     5.0              NaN  Short Trip     2000  Medium Trip
# 2     4.8  Errand/Supplies  Short Trip     2000        Short
# 3     4.7          Meeting  Short Trip     2000        Short
# 4    63.7   Customer Visit   Long Trip     2000    Long Trip

# %%
df.groupby("START*")["MILES*"].mean()
# Out:
# START*
# Agnew                2.775000
# Almond              15.200000
# Apex                 5.341176
# Arabi               17.000000
# Arlington            4.900000
#                       ...
# West University      2.200000
# Weston               4.000000
# Westpark Place       2.182353
# Whitebridge          4.020588
# Winston Salem      133.600000
# Name: MILES*, Length: 176, dtype: float64

# %%
df.groupby(["START*","STOP*"])["MILES*"].agg(["mean","sum"]).head(20)
# Out:
#                                                            mean    sum
# START*                    STOP*
# Agnew                     Agnew                        2.200000    2.2
#                           Cory                         4.300000    4.3
#                           Renaissance                  2.300000    4.6
# Almond                    Bryson City                 15.200000   15.2
# Apex                      Apex                         2.150000    4.3
#                           Cary                         5.792308   75.3
#                           Eagle Rock                   2.200000    2.2
#                           Holly Springs                9.000000    9.0
# Arabi                     Metairie                    17.000000   17.0
# Arlington                 Washington                   4.900000    4.9
# Arlington Park at Amberly Lexington Park at Amberly    1.300000    1.3
# Asheville                 Mebane                     195.900000  195.9
# ...

# %% [markdown]
# ------------IN CLASS ASSIGNMENT---------------------
#
# Find most recent and the earliest travelled date and mean distance travelled for each start city

# %%
df.tail()
df=df.iloc[:-1,:]

df["START_DATE*"]=pd.to_datetime(df["START_DATE*"])
df.dtypes
# Out:
# <ipython-input-184-f5877e988a85>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["START_DATE*"]=pd.to_datetime(df["START_DATE*"])
# START_DATE*    datetime64[ns]
# END_DATE*              object
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# miles_cat              object
# My_year                 int32
# NewMiles               object
# dtype: object

# %%
#HAVING ERROR FOR BELOW ASSIGNMENT
#res= df.groupby("START*").agg({"MILES*":["mean"],"START_DATE*":["mean","max"]}) 
#res

# %% [markdown]
# *****************LOOPS AND FUNCTIONS*************

# %%
#basic for loop
res=[]
temp=[1,2,3,4]
for i in temp:
    res.append(i*i)
res
# Out:
# [1, 4, 9, 16]

# %%
#List comprehention
[x*x for x in temp]
# Out:
# [1, 4, 9, 16]

# %%
store_sales=pd.read_csv("store_sales.csv")

# %%
store_sales.head()
# Out:
#   store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0      S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1      S_2  California   12   19   15   15   11   19     7   15   10   11
# 2      S_3  California   16   16   14   19   23    6    13   13   15   14
# 3      S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4      S_5       Texas   19    5   24    9    5   24    10    5   24   15
#
#    Nov  Dec
# 0    7    6
# 1   21   19
# 2   24    8
# 3    7   11
# 4    6   13

# %%
store_sales["Jan"].mean()
# Out:
# 14.46

# %%
##apply function will give us avg for all the col seperately(it doesn't consider string col type)
store_sales.apply("mean")
# Out:
# Jan     14.46
# Feb     15.09
# Mar     14.56
# Apr     14.57
# May     13.56
# Jun     13.80
# July    14.38
# Aug     15.81
# Sep     14.91
# Oct     14.10
# Nov     15.31
# Dec     13.57
# dtype: float64

# %%
# to cal mean horizontally or for the rows
store_sales.apply("mean",axis=1)
#here axis=1 means row wise means avg will be by row wise and if it is axis=0 means avg will be col wise
# Out:
# 0     14.833333
# 1     14.500000
# 2     15.083333
# 3     11.250000
# 4     13.250000
#         ...
# 95    15.416667
# 96    12.833333
# 97    14.000000
# 98    14.416667
# 99    15.000000
# Length: 100, dtype: float64

# %%
##if we are having error for the datatype like for string datatype for i/p 118 
##then do following query
store_sales.select_dtypes(include=['int64','float64']).apply("mean")
# Out:
# Jan     14.46
# Feb     15.09
# Mar     14.56
# Apr     14.57
# May     13.56
# Jun     13.80
# July    14.38
# Aug     15.81
# Sep     14.91
# Oct     14.10
# Nov     15.31
# Dec     13.57
# dtype: float64

# %%
store_sales.groupby["city"].agg("mean")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-194-08c4394a4095> in <module>
# ----> 1 store_sales.groupby["city"].agg("mean")
#
# TypeError: 'method' object is not subscriptable

# %%
#define function in python
def add(a,b):
    res= a + b
    return res
add(3,4)

# %%
def bonus_func(sales_numbers):
    return ["Eligible" if x>15 else "Not Eligible" for x in sales_numbers]

# %%
bonus_func([12,23,56])

# %%
# another way to display above function
def bonus_func(sales_col):
    elig_values = np.where(sales_col>10,"eligible","Not eligible")
    return elig_values
store_sales["Jan_bonus"]=bonus_func(store_sales["Jan"])
store_sales
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0       S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1       S_2  California   12   19   15   15   11   19     7   15   10   11
# 2       S_3  California   16   16   14   19   23    6    13   13   15   14
# 3       S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4       S_5       Texas   19    5   24    9    5   24    10    5   24   15
# ..      ...         ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...
# 95     S_96       Texas    7   10   20   20   10   15    15   21   15    7
# 96     S_97  California   13    6    7   15   22   10    21   23   10    6
# 97     S_98       Texas   16    9    6   14   20   13    11   10    8   22
# 98     S_99     Arizona   18   16    9    5   12   22    11   13   21   17
# 99    S_100  California    5   23   17   24   15   21    19   10   12   20
#
#     Nov  Dec     Jan_bonus
# 0     7    6  Not eligible
# ...

# %%
# if we don't know about the next month bonus like if this month will give bonus > 10 and for next will give 20 and for every month we have to enter the sales no,so do following
# another way to display above function
def bonus_func(sales_col,sales_num):
    elig_values = np.where(sales_col>sales_num,"eligible","Not eligible")
    return elig_values
#store_sales["Jan_bonus"]=bonus_func(store_sales["Jan"])
#store_sales

# %%
# we can apply eligible and not eligible to all col:
def bonus_func(sales_col):
    elig_values = np.where(sales_col>10,"eligible","Not eligible")
    return elig_values
#store_sales["Jan_bonus"]=bonus_func(store_sales["Jan"])
#store_sales
newdf=store_sales.select_dtypes(include=["int64","float64"]).apply(bonus_func)
newdf
# Out:
#              Jan           Feb           Mar           Apr           May  \
# 0   Not eligible      eligible      eligible      eligible      eligible
# 1       eligible      eligible      eligible      eligible      eligible
# 2       eligible      eligible      eligible      eligible      eligible
# 3   Not eligible      eligible      eligible  Not eligible      eligible
# 4       eligible  Not eligible      eligible  Not eligible  Not eligible
# ..           ...           ...           ...           ...           ...
# 95  Not eligible  Not eligible      eligible      eligible  Not eligible
# 96      eligible  Not eligible  Not eligible      eligible      eligible
# 97      eligible  Not eligible  Not eligible      eligible      eligible
# 98      eligible      eligible  Not eligible  Not eligible      eligible
# 99  Not eligible      eligible      eligible      eligible      eligible
#
#              Jun          July           Aug           Sep           Oct  \
# ...

# %%
raghu=pd.concat([store_sales,newdf],axis=1)
raghu
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun July Aug  ...  \
# 0       S_1       Texas    8   20   13   21   17   20   24  17  ...
# 1       S_2  California   12   19   15   15   11   19    7  15  ...
# 2       S_3  California   16   16   14   19   23    6   13  13  ...
# 3       S_4       Texas    8   18   13   10   14   14    6   8  ...
# 4       S_5       Texas   19    5   24    9    5   24   10   5  ...
# ..      ...         ...  ...  ...  ...  ...  ...  ...  ...  ..  ...
# 95     S_96       Texas    7   10   20   20   10   15   15  21  ...
# 96     S_97  California   13    6    7   15   22   10   21  23  ...
# 97     S_98       Texas   16    9    6   14   20   13   11  10  ...
# 98     S_99     Arizona   18   16    9    5   12   22   11  13  ...
# 99    S_100  California    5   23   17   24   15   21   19  10  ...
#
#              Mar           Apr           May           Jun          July  \
# 0       eligible      eligible      eligible      eligible      eligible
# ...

# %%
raghu.tail()
# Out:
#    store_id city           Jan           Feb           Mar           Apr  \
# 95      NaN  NaN  Not eligible  Not eligible      eligible      eligible
# 96      NaN  NaN      eligible  Not eligible  Not eligible      eligible
# 97      NaN  NaN      eligible  Not eligible  Not eligible      eligible
# 98      NaN  NaN      eligible      eligible  Not eligible  Not eligible
# 99      NaN  NaN  Not eligible      eligible      eligible      eligible
#
#              May           Jun      July           Aug           Sep  \
# 95  Not eligible      eligible  eligible      eligible      eligible
# 96      eligible  Not eligible  eligible      eligible  Not eligible
# 97      eligible      eligible  eligible  Not eligible  Not eligible
# 98      eligible      eligible  eligible      eligible      eligible
# 99      eligible      eligible  eligible  Not eligible      eligible
#
#              Oct           Nov           Dec Jan_bonus
# 95  Not eligible      eligible      eligible       NaN
# ...
